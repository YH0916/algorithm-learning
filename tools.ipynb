# %% [markdown]
# 一维数组初始化
# 适合背包问题、最长子序列问题等。

# %%
# 长度为 n+1 的一维数组，初始值为 0
dp = [0] * (n + 1)

# 如果要初始化成 -1 或 inf
dp = [-1] * (n + 1)
dp = [float("inf")] * (n + 1)

# %% [markdown]
# 二维数组初始化
# 适合编辑距离、二维背包、最长公共子序列等。

# %%
dp=[[0]*(n+1) for _ in range(m+1)] # 最后生成的是m+1行，n+1列的为0的矩阵

# %% [markdown]
# 三维数组初始化
# 适合状态机 DP（比如股票买卖问题，带天数、交易次数、是否持股三种维度）。

# %%
dp=[[[0]*(k+1) for _ in range(n+1)] for _ in range(m+1)]
