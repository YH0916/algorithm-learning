# %% [markdown]
# # 二叉堆

# %% [markdown]
# 二叉堆是一个完全二叉树，主要操作是两个，sink 下沉； swim 上浮，用于维护二叉堆的性质
# 应用有两个，一个是数据结构优先级队列，一个是实现排序方法堆排序

# %% [markdown]
# 二叉堆是一种能够动态排序的数据结构，能实现此功能的是优先级队列（底层用二叉堆实现），二叉搜索树。
# 二叉树上任意节点的值，都必须大于或等于（或者小于或等于）其左右字数所有节点的值，如果是大于等于，成为“大顶堆”，根节点就是整个树上最大的值，反之称为“小顶堆”根节点就是整个树上最小的值。
# 一个二叉堆的左右子堆也是一个二叉堆
